# %%
import numpy as np

# %%
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import optimizers

# %%
x = np.arange(-1, 1, 0.001)
np.random.shuffle(x)
y = x**2 + np.sin(x*10)

plt.scatter(x, y)
plt.show()

# %%
index = int(len(x)*0.8)
train_x, test_x = x[:index], x[index:]
train_y, test_y = y[:index], y[index:]

plt.scatter(train_x, train_y)
plt.show()
plt.scatter(test_x, test_y)
plt.show()

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(1))

model.compile(optimizer = "SGD",loss="mse",metrics=["mae"])

hist = model.fit(train_x,train_y,validation_split = 0.2,epochs = 100, batch_size = 10,steps_per_epoch=10,verbose = False)
plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="loss")
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(1))

model.compile(optimizer = "SGD",loss="mse",metrics=["mae"])

hist = model.fit(train_x,train_y,validation_split = 0.2,epochs = 100, batch_size = 10,steps_per_epoch=10000)
plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 10000/10000 [==============================] - 29s 3ms/step - loss: 0.3774 - mae: 0.5091 - val_loss: 0.2891 - val_mae: 0.4363
# Epoch 2/100
# ...
# 10000/10000 [==============================] - 7s 693us/step - loss: 0.2159 - mae: 0.3602 - val_loss: 0.0979 - val_mae: 0.2281

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# steps_per_epoch * epochs <= 데이터 수가 유지된다. 학습에 사용되는 데이터는 중복되지 않기 때문이다. 그래서 steps_per_epoch는 자동 계산으로 두는 것이 좋은 방법이다.

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(1))

model.compile(optimizer = "SGD",loss="mse",metrics=["mae"])

hist = model.fit(train_x,train_y,validation_split = 0.2,epochs = 100, batch_size = 10,verbose = False)
plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %%
train_x.shape[0]
# Out:
# 1600

# %%
batch_size =10
stepsize = train_x.shape[0] * 0.8 /  batch_size
stepsize == 128
# Out:
# True

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(10,activation = "tanh"))
model.add(Dense(1))

model.compile(optimizer = "Adam",loss="mse",metrics=["mae"])

hist = model.fit(train_x,train_y,validation_split = 0.1,epochs = 100, batch_size = 128,verbose=False)
plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="Adam")

hist = model.fit(train_x, train_y, epochs=100, batch_size=128, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# ## batch size를 줄여서 학습 횟수를 증가시켰다.

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="Adam")

hist = model.fit(train_x, train_y, epochs=100, batch_size=10, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# ## Optimizer = AdaGrad

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1),activation="sigmoid")

model.compile(loss="mse", optimizer="AdaGrad")

hist = model.fit(train_x, train_y, epochs=100, batch_size=128, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# ### batch 사이즈를 줄여서 학습 횟수를 높였다.

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="AdaGrad")

hist = model.fit(train_x, train_y, epochs=100, batch_size=10, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# ### 은닉층의 활성화 함수를 ReLU로 변경

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="ReLU"))
model.add(Dense(10, activation="ReLU"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="AdaGrad")

hist = model.fit(train_x, train_y, epochs=100, batch_size=10, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="RMSProp")

hist = model.fit(train_x, train_y, epochs=100, batch_size=128, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="tanh"))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="RMSProp")

hist = model.fit(train_x, train_y, epochs=100, batch_size=10, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# - batch 사이즈를 줄일수록 학습횟수가 증가해 loss, val_loss의 간격이 줄어들고, loss가 감소하지만 학습 시간이 증가한다.

# %% [markdown]
# ### 은닉층의 활성화 함수를 ReLU로 변경

# %%
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation="ReLU"))
model.add(Dense(10, activation="ReLU"))
model.add(Dense(1))

model.compile(loss="mse", optimizer="RMSProp")

hist = model.fit(train_x, train_y, epochs=100, batch_size=10, validation_split=0.1,verbose = False)

plt.plot(hist.history["loss"],label="loss")
plt.plot(hist.history["val_loss"],label="val_loss")
plt.legend()
plt.show()

# %%
y_ = model.predict(test_x)
plt.scatter(test_x, test_y)
plt.scatter(test_x, y_)
plt.show()

# %% [markdown]
# 데이터 셋의 특성에 따라 다양한 조합을 시도해봐야한다. hidden layer의 구조, 구성 역시 적절히 변경해야한다. (padding, pooling, dropout, Activation fun, optimizers)
